# %%
import pandas as pd

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
stats=pd.read_csv('F:\\notes\\sem-6\\termpaper\\kluedited.csv')

# %%
stats
# Out:
#       VillageName  Name of the Head of the Family Residence_Status      TOH  \
# 0        Prathuru                             NaN     Own Property  Bunglow
# 1        Prathuru                             NaN           Rented  Bunglow
# 2        Nuthakki                             NaN     Own Property    Pucca
# 3        Nuthakki                             NaN     Own Property      Hut
# 4        Nuthakki                             NaN           Rented  Bunglow
# 5        Nuthakki                             NaN           Rented  Bunglow
# 6        Nuthakki                             NaN     Own Property  Bunglow
# 7        Nuthakki                             NaN     Own Property  Bunglow
# 8      Mellempudi                             NaN     Own Property  Bunglow
# 9      Mellempudi                             NaN     Own Property  Bunglow
# 10     Mellempudi                             NaN     Own Property      Hut
# ...

# %%
stats.columns
# Out:
# Index(['VillageName', 'Name of the Head of the Family', 'Residence_Status',
#        'TOH', 'SOD', 'SOCF', 'Toilets', 'SOI', 'Income', 'Hygiene', 'People',
#        'Illiterates', 'Unemployed_youth', 'HealthCheckup6m', 'Mobiles/Family',
#        'Opinion_Demonitization', 'BankAcc',
#        'Does your family members know Card usage?', 'Smartphone',
#        'InternetAccess', 'Did you ever make a Cashless Transaction?',
#        'Willingness to go Cashless/Digital',
#        'How capable are you to go cashless using Mobile? (Smart/ Normal)',
#        'Can you keep yourself secure from Cyber-fraud?', 'Any comments', '_id',
#        '_uuid', '_submission_time', 'Adults60', 'Children15',
#        'Type of study of children', 'Women_H', 'PHC',
#        'Number of Mobile Phones in the House?', 'Do you have a ATM CARD?',
#        'Does all the adults in your family know Card usage?',
#        'How frequent you visit bank monthly?', 'Do you use Internet Banking?',
# ...

# %%
data=stats[['VillageName','Residence_Status']]
data1=data.head(15)
data1
# Out:
#    VillageName Residence_Status
# 0     Prathuru     Own Property
# 1     Prathuru           Rented
# 2     Nuthakki     Own Property
# 3     Nuthakki     Own Property
# 4     Nuthakki           Rented
# 5     Nuthakki           Rented
# 6     Nuthakki     Own Property
# 7     Nuthakki     Own Property
# 8   Mellempudi     Own Property
# 9   Mellempudi     Own Property
# 10  Mellempudi     Own Property
# 11     Ippatam     Own Property
# 12  Mellempudi     Own Property
# 13  Peddapalem           Rented
# 14     Ippatam     Own Property

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.get_dummies(data1,columns=['Residence_Status'])
# Out:
#    VillageName  Residence_Status_Own Property  Residence_Status_Rented
# 0     Prathuru                              1                        0
# 1     Prathuru                              0                        1
# 2     Nuthakki                              1                        0
# 3     Nuthakki                              1                        0
# 4     Nuthakki                              0                        1
# 5     Nuthakki                              0                        1
# 6     Nuthakki                              1                        0
# 7     Nuthakki                              1                        0
# 8   Mellempudi                              1                        0
# 9   Mellempudi                              1                        0
# 10  Mellempudi                              1                        0
# 11     Ippatam                              1                        0
# ...

# %%
stats.Income[0:10]
# Out:
# 0    Bank
# 1    Bank
# 2    Cash
# 3    Cash
# 4    Cash
# 5    Bank
# 6    Cash
# 7    Cash
# 8    Bank
# 9    Cash
# Name: Income, dtype: object

# %%
stats.Income.replace(('Bank','Cash'),(1,0),inplace=True)

# %%
stats.Income[0:10]
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# 5    1
# 6    0
# 7    0
# 8    1
# 9    0
# Name: Income, dtype: int64

# %%
stats.Residence_Status.replace(('Own Property','Rented'),(1,0),inplace=True)
stats.Residence_Status[0:10]

# %%
stats.head()
# Out:
#   VillageName  Name of the Head of the Family  Residence_Status      TOH  \
# 0    Prathuru                             NaN                 1  Bunglow
# 1    Prathuru                             NaN                 0  Bunglow
# 2    Nuthakki                             NaN                 1    Pucca
# 3    Nuthakki                             NaN                 1      Hut
# 4    Nuthakki                             NaN                 0  Bunglow
#
#           SOD  SOCF  Toilets          SOI  Income  Hygiene  ...    \
# 0  Purchasing   Gas  Private     Business       1     Neat  ...
# 1  Purchasing   Gas  Private          Job       1     Neat  ...
# 2        Pump  Wood  Private  Agriculture       0  Average  ...
# 3        Pump  Wood     Open  Agriculture       0     Poor  ...
# 4        Pump   Gas  Private  Agriculture       0  Average  ...
#
#    Do you use Paytm or other Digital Methods?  \
# 0                                         YES
# ...

# %% [markdown]
# visualization---
# 1.

# %%
vis1=sns.distplot(stats["Residence_Status"])

# %%
vis2= sns.heatmap(data=stats,x='VillageName',y='Residence_Status')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-d459f6268005> in <module>()
# ----> 1 vis2= sns.heatmap(data=stats,x='VillageName',y='Residence_Status')
#
# C:\Users\venkataraja\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, ax, xticklabels, yticklabels, mask, **kwargs)
#     483     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     484                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 485                           yticklabels, mask)
#     486
#     487     # Add the pcolormesh kwargs here
#
# ...

# %%
enc=OneHotEncoder()

# %%
OneHotEncoder(n_values='auto', categorical_features='all', dtype=<...'numpy.float64'>, sparse=True, handle_unknown='error')
# Out:
#   File "<ipython-input-42-6349702b5202>", line 1
#     OneHotEncoder(n_values='auto', categorical_features='all', dtype=<...'numpy.float64'>, sparse=True, handle_unknown='error')
#                                                                      ^
# SyntaxError: invalid syntax
